# %%
'''import myStack as s
inStk = s.stack()'''


# function block:

def reverse_a_part(inStk,k):

    l = len(inStk.stk)
    
    outStk = s.stack()
    temp=s.stack()
    
    for x in range(l-k):
        temp.push(inStk.pop())

    x=0
    for x in range(l):
        if x<k:
            outStk.push(inStk.pop())
        else:
            outStk.push(temp.pop())

    del temp,inStk
        
    return outStk.stk



"""
while True:
    print(''' \n1. Push
                2. Pop
                3. Exit  ''')
    choice = int(input('enter the choice\n'))

    if choice == 1:
        inStk.push(int(input('enter the no.\n')))
        print(inStk.prnt())
        
    elif choice == 2:
        inStk.pop()
        print(inStk.prnt())

    elif choice == 3:
        break

    else:
        print('invalid choice\n')



k = int(input('enter K\n'))

print('input list ', inStk.stk)
print('\nlist after reversing ',k,' places is ',reverse_a_part(inStk,k))
print('\ninput list ', inStk.stk)

"""
